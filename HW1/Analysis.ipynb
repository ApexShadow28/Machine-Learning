# %% [markdown]
# <a href="https://colab.research.google.com/github/ApexShadow28/Machine-Learning/blob/main/HW1/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Save directly to GitHub from Colab's File menu

# %% [markdown]
# They all worked as expected

# %% [markdown]
# Press the new repository button in the top left and name it. Then when uploading a Collab notebook to Github, put the name of the folder you want to put it in in the front.

# %% [markdown]
# You need strong Python fundamentals to properly format, clean, and pass data into machine learning models.
